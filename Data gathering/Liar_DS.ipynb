# %%
import pandas as pd
import numpy as np
from scipy.sparse import hstack

import textstat
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import stanfordnlp
from textblob import TextBlob

from nltk.tokenize import RegexpTokenizer
from nltk import WordNetLemmatizer

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import BernoulliNB 
from sklearn.naive_bayes import MultinomialNB

# %%
df = pd.read_csv('../datasets/buzzfeed-v02-originalLabels.txt', sep='\t', header=None )
df.head()
# Out:
#       0                                                  1  \
# 0  1204  http://occupydemocrats.com/2016/09/23/donald-t...
# 1  1157  http://occupydemocrats.com/2016/09/19/just-50-...
# 2  1165  http://occupydemocrats.com/2016/09/20/proof-tr...
# 3  1199  http://occupydemocrats.com/2016/09/23/breaking...
# 4  1210  http://occupydemocrats.com/2016/09/26/wwii-vet...
#
#                            2  \
# 0                mostly true
# 1                mostly true
# 2  mixture of true and false
# 3                mostly true
# 4                mostly true
#
#                                                    3                    4  \
# 0   A few days ago, DonaldTrump despicable spawn ...  occupydemocrats.com
# 1   A group of over fifty former intelligence off...  occupydemocrats.com
# 2   A new investigation has determined that Donal...  occupydemocrats.com
# 3   A new video has emerged of the moments before...  occupydemocrats.com
# 4   A ninety-six-year-old World War II veteran an...  occupydemocrats.com
#
#           5
# 0  buzzfeed
# 1  buzzfeed
# 2  buzzfeed
# 3  buzzfeed
# 4  buzzfeed

# %%
df[2].value_counts(normalize = True)
# Out:
# mostly true                  0.789855
# mixture of true and false    0.123188
# mostly false                 0.046377
# no factual content           0.040580
# Name: 2, dtype: float64

# %%
df = df[df[2] != 'no factual content']

df = df[[1, 2, 3]]

df.columns = ['URL', 'label', 'text']

df = df[['label', 'URL', 'text']]

# %%
df.head()
# Out:
#                        label  \
# 0                mostly true
# 1                mostly true
# 2  mixture of true and false
# 3                mostly true
# 4                mostly true
#
#                                                  URL  \
# 0  http://occupydemocrats.com/2016/09/23/donald-t...
# 1  http://occupydemocrats.com/2016/09/19/just-50-...
# 2  http://occupydemocrats.com/2016/09/20/proof-tr...
# 3  http://occupydemocrats.com/2016/09/23/breaking...
# 4  http://occupydemocrats.com/2016/09/26/wwii-vet...
#
#                                                 text
# 0   A few days ago, DonaldTrump despicable spawn ...
# 1   A group of over fifty former intelligence off...
# 2   A new investigation has determined that Donal...
# 3   A new video has emerged of the moments before...
# 4   A ninety-six-year-old World War II veteran an...

# %%
df_2 = pd.read_csv('../datasets/snopes_checked_v02.csv', encoding='iso-8859-1' )
df_2.sample(10)
# Out:
#     fact_rating_phase1                                  snopes_url_phase1  \
# 60               FALSE  https://www.snopes.com/fact-check/gates-of-hea...
# 63               FALSE  https://www.snopes.com/fact-check/fbi-wasserma...
# 44             mixture      https://www.snopes.com/fact-check/emordnilap/
# 179       mostly false  https://www.snopes.com/fact-check/senate-vote-...
# 252            mixture  https://www.snopes.com/fact-check/members-cong...
# 157        mostly true  https://www.snopes.com/fact-check/bills-introd...
# 168       mostly false  https://www.snopes.com/fact-check/peanut-butte...
# 144       mostly false  https://www.snopes.com/fact-check/thomas-ediso...
# 297               TRUE  https://www.snopes.com/fact-check/woman-prosec...
# 108              FALSE  https://www.snopes.com/fact-check/greenpeace-a...
#
#                                   article_title_phase1  \
# 60                          Gates of Heaven Photograph
# 63   Did The Federal Bureau of Investigation Seize ...
# 44                                          Emordnilap
# 179  Senate Voted 51-48 to Repeal the Affordable Ca...
# 252     Do Members of Congress Enjoy Free Health Care?
# 157  Bills Introduced by Republicans While We Were ...
# 168  Three Reasons You Should Stop Eating Peanut Bu...
# 144  Thomas Edisons Mom Lied about a Letter Expelli...
# 297  Woman Prosecuted for Laughing During Jeff Sess...
# 108  Did a Greenpeace Activist Get His Arm Bitten O...
#
#     article_category_phase1 article_date_phase1  \
# 60             Fauxtography           22-Jan-16
# 63                 Politics           26-Jul-17
# 44                 Language           13-Dec-14
# 179           Uncategorized           27-Jan-17
# 252                Politics           15-Mar-17
# 157                Politics            7-Mar-17
# 168        Science  Medical           31-Mar-17
# 144                 History            1-Dec-16
# 297           Legal Affairs            3-May-17
# 108               Fake News            2-Feb-18
#
#                                   article_claim_phase1  \
# 60   Scientists are stumped by a photograph taken b...
# 63   FBI agents raided Rep. Debbie Wasserman-Schult...
# 44   "Emordnilap" is a real word referring to words...
# 179  The senate voted 51-48 to repeal the Affordabl...
# 252  Congressional members receive free, high-quali...
# 157  Legislation introduced by Republicans during P...
# 168  Three additives in peanut butter cups, soy lec...
# 144  Thomas Edisons mother lied about the contents ...
# 297  Code Pink member Desiree Fairooz was prosecute...
# 108  A Greenpeace activist had his arm bitten off w...
#
#                              article_origin_url_phase1  \
# 60          http://www.eso.org/public/images/eso1119a/
# 63                             http://archive.is/aBCGK
# 44      http://www.merriam-webster.com/dictionary/word
# 179  https://www.congress.gov/bill/115th-congress/s...
# 252  http://www.factcheck.org/2013/05/congress-and-...
# 157                            http://archive.is/zXeMT
# 168                            http://archive.is/W7VJ5
# 144  https://www.nps.gov/edis/learn/historyculture/...
# 297  https://www.nytimes.com/2017/05/03/us/code-pin...
# 108                           https://archive.is/Mg9Ac
#
#      index_paragraph_phase1  page_is_first_citation_phase1 error_phase2  \
# 60                        3                          False     No Error
# 63                        1                          False     No Error
# 44                        3                          False     No Error
# 179                       3                           True     No Error
# 252                       2                          False     No Error
# 157                       1                           True     No Error
# 168                       1                          False     No Error
# 144                       4                           True     No Error
# 297                       2                          False     No Error
# 108                       1                           True     No Error
#
#                           original_article_text_phase2  \
# 60   VST image of the star-forming region Messier 1...
# 63   Ever since Trump got into office, liberals con...
# 44   The word word has a wide range of meanings and...
# 179  Array (  => 2017-01-13 [displayText] => Passed...
# 252  Q: Is it true that there are bills in Congress...
# 157  The Republican-led Congress is wasting no time...
# 168  If youre reading this, Ill assume youve had a ...
# 144  Young Thomas Edison. NPS Photo Thomas Alva Edi...
# 297  A jury on Wednesday convicted three Code Pink ...
# 108  An environmental activist was almost killed Ye...
#
#                                   article_title_phase2 publish_date_phase2  \
# 60     VST image of the star-forming region Messier 17                 NaN
# 63   FBI Raided Wasserman-Schultzs House After Shes...           7/26/2017
# 44               Definition of Word by Merriam-Webster                 NaN
# 179  S.Con.Res.3 - 115th Congress (2017-2018): A co...                 NaN
# 252          Congress and an Exemption from Obamacare?           3/13/2005
# 157  While we were distracted by Trump, Republicans...           5/17/2003
# 168  3 Reasons Why You Should Stop Eating Peanut Bu...           3/30/2017
# 144  Thomas Edison National Historical Park (U.S. N...                 NaN
# 297  A Code Pink Protester Laughs Over a Trump Nomi...           3/17/2005
# 108  Greenpeace activist gets arm bitten off after ...           2/18/2002
#
#            author_phase2 Jerry-label  Jill-label Fatemeh-label  \
# 60   Information Eso.Org       right  irrelevant       context
# 63                   NaN       right       right         right
# 44        Michael Mccann  irrelevant  irrelevant     ambiguous
# 179                 Enzi     context     context             n
# 252       Lori Robertson   debunking   debunking             n
# 157                  NaN       right       right             n
# 168                  NaN       right       right             n
# 144                  NaN     context     context             n
# 297                  NaN       right       right             n
# 108                  NaN       right       right             n
#
#                   notes  original order Agreement
# 60                photo              61         x
# 63                  NaN              64       NaN
# 44   context/irrelevant              45       NaN
# 179                 NaN             180       NaN
# 252                 NaN             253       NaN
# 157                 NaN             158       NaN
# 168                 NaN             169       NaN
# 144                 NaN             145       NaN
# 297                 NaN             298       NaN
# 108                 NaN             109       NaN

# %%
df_2.shape
# Out:
# (312, 20)

# %%
df_2['original_article_text_phase2'][1]
# Out:
# 'As of right now I dont know what kinds of animals they are using.\r\r Kenn\r\rAnimal testing for cosmetics is a hot topic in the beauty industry, with most consumers and many companies deciding to avoid products made with animal testing. After more than two decades following a no testing on animals policy, cosmetics giants Avon, Mary Kay, and Estee Lauder have resumed the practice without letting consumers know. In the late 1980s, PETAs Avon Killing campaign eventually led to the company banning animal testing for their products, with Mary Kay and Este Lauder following suit.\r\rAccording to a press release from Rush PR, the news was broken after animal rights organization PETA removed the companies from their cruelty-free list after discovering that they had returned to using testing on animals for their products. The three companies began the tests again in order to satisfy regulations from the Chinese government so they could sell their products in China. However, PETA contends that there are alternative testing methods that are just as effective and widely used in the US.\r\rKathy Guillermo, the Vice President of PETAs Laboratory Investigations was saddened by the move: Avon, Este Lauder, and Mary Kay have regressed a generation: Their products are once again being dripped into rabbits eyes and smeared onto animals abraded skin. Shes urging customers to choose cruelty-free products instead.\r\rAvon spokeswoman Reese Witherspoon may be upset to learn about the new animal testing as well. Late last year she was dismayed to learn a bag she was spotted with was made from real python skin and agreed to throw it away. But perhaps she can use her star power to influence Avon to go back to their animal-friendly ways.'

# %%
df_2['fact_rating_phase1'].value_counts(normalize = True)
# Out:
# mixture         0.230769
# mostly true     0.227564
# TRUE            0.208333
# mostly false    0.169872
# FALSE           0.163462
# Name: fact_rating_phase1, dtype: float64

# %%
df_2 = df_2[['fact_rating_phase1', 'snopes_url_phase1', 'original_article_text_phase2']]

df_2.columns = ['label', 'URL', 'text']

df_2.head()
# Out:
#      label                                                URL  \
# 0  mixture  https://www.snopes.com/fact-check/elizabeth-wa...
# 1  mixture  https://www.snopes.com/fact-check/the-company-...
# 2  mixture  https://www.snopes.com/fact-check/hillary-clin...
# 3  mixture  https://www.snopes.com/fact-check/light-fingered/
# 4  mixture  https://www.snopes.com/fact-check/va-hospital-...
#
#                                                 text
# 0  Elizabeth Warren, the Harvard Law School profe...
# 1  As of right now I dont know what kinds of anim...
# 2  \r\r\r\r\r\r  Former Secretary of State Hillar...
# 3  Crushing Lamps\r\rCrushing and breaking fluore...
# 4  This was their response: "Logistically, we cou...

# %%
df = pd.concat([df, df_2])

df.sample(10)
# Out:
#                           label  \
# 49                      mixture
# 2     mixture of true and false
# 1292                mostly true
# 37    mixture of true and false
# 569                mostly false
# 491                 mostly true
# 366                 mostly true
# 768                 mostly true
# 519                 mostly true
# 717   mixture of true and false
#
#                                                     URL  \
# 49    https://www.snopes.com/fact-check/trump-anti-g...
# 2     http://occupydemocrats.com/2016/09/20/proof-tr...
# 1292                              http://cnn.it/2cRGTGk
# 37                                http://cnn.it/2deCyLx
# 569   http://www.addictinginfo.org/2016/09/19/proof-...
# 491                            http://politi.co/2d4NwH7
# 366                               http://cnn.it/2dnoYpa
# 768                            http://politi.co/2d8M4PU
# 519   http://occupydemocrats.com/2016/09/22/just-bar...
# 717   http://rightwingnews.com/hillary-clinton-2/nav...
#
#                                                    text
# 49    Signup to receive a daily roundup of the top L...
# 2      A new investigation has determined that Donal...
# 1292  Washington  Hillary Clinton is leading Donald ...
# 37     Former President George H.W. Bush said Monday...
# 569   I woke up this morning to find a variation of ...
# 491   Former New York City Mayor Rudy Giuliani rippe...
# 366   Critical Counties is a CNN series exploring 11...
# 768   On Media Blog Archives Select Date? December, ...
# 519   He?s basically a bully, but like all bullies,h...
# 717   Navy Seal Does What Others REFUSE To, Fact Che...

# %%
df.index = range(0, len(df.index))

# %%
df.to_csv('../combined_bfsnopes.csv')

# %% [markdown]
# ### Feature engineering

# %%
dc_score = []
for i in df.index:
    score = textstat.dale_chall_readability_score(df['text'][i])
    dc_score.append(score)

df['dc_score'] = dc_score

# %%
subjectivity = []
for i in df.index:
    text = TextBlob(df['text'][i])
    sub = text.sentiment
    subjectivity.append(sub[1])

df['sub'] = subjectivity

# %%
analyzer = SentimentIntensityAnalyzer()
vs_list = []
for i in df.index:
    vs = analyzer.polarity_scores(df['text'][i])
    vs_list.append(vs['neu'])

df['vs'] = vs_list

# %%
df.sample(5)
# Out:
#             label                                                URL  \
# 1316  mostly true  http://www.addictinginfo.org/2016/09/21/dixie-...
# 732   mostly true                           http://politi.co/2doAYGE
# 1144  mostly true  http://www.addictinginfo.org/2016/09/19/chelse...
# 1067  mostly true                           http://politi.co/2cBjhCQ
# 1261  mostly true                              http://cnn.it/2cPYxdT
#
#                                                    text  dc_score       sub  \
# 1316  With this presidential election being as absol...      7.12  0.522531
# 732   On Media Blog Archives Select Date? December, ...      7.66  0.394545
# 1144  There may be a few women out there who enjoy a...      6.55  0.365212
# 1067  The ad praises Donald Trump for ?doing what ot...     10.05  0.446014
# 1261  Washington  With two months to go before Elect...      7.20  0.410722
#
#          vs
# 1316  0.801
# 732   0.826
# 1144  0.748
# 1067  0.814
# 1261  0.865

# %%
def tokenize(x):
    tokenizer = RegexpTokenizer(r'\w+')
    return tokenizer.tokenize(x)

df['tokens'] = df['text'].map(tokenize)

text_length = []
for i in df.index:
    length = len(df['tokens'][i])
    text_length.append(length)



    
def lemmatize(x):
    lemmatizer = WordNetLemmatizer()
    return ' '.join([lemmatizer.lemmatize(word) for word in x])

df['lemma'] = df['tokens'].map(lemmatize)

# %%
average_word_lengths = []

for i in df.index:
    token_lens = [len(token) for token in df['tokens'][i]]
    average_word_lengths.append(np.mean(token_lens))

    
df['avg_word_len'] = average_word_lengths
# Out:
# C:\Users\Ishan\Anaconda3\envs\nltktb\lib\site-packages\numpy\core\fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\Ishan\Anaconda3\envs\nltktb\lib\site-packages\numpy\core\_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
df['text_length'] = text_length

# %%
df['label'].value_counts(normalize=True)
# Out:
# mostly true                  0.710092
# mixture of true and false    0.103976
# mostly false                 0.070948
# mixture                      0.044037
# TRUE                         0.039755
# FALSE                        0.031193
# Name: label, dtype: float64

# %%
df['label'] = df['label'].map({'mostly true' : 2, 'mixture of true and false' : 1, 'mostly false' : 0, 'mixture' : 1, 'TRUE' : 3, 'FALSE' : 0})

# %%
df['label'].value_counts(normalize = True)
# Out:
# 2    0.710092
# 1    0.148012
# 0    0.102141
# 3    0.039755
# Name: label, dtype: float64

# %%
df.head()
# Out:
#    label                                                URL  \
# 0      2  http://occupydemocrats.com/2016/09/23/donald-t...
# 1      2  http://occupydemocrats.com/2016/09/19/just-50-...
# 2      1  http://occupydemocrats.com/2016/09/20/proof-tr...
# 3      2  http://occupydemocrats.com/2016/09/23/breaking...
# 4      2  http://occupydemocrats.com/2016/09/26/wwii-vet...
#
#                                                 text  dc_score       sub  \
# 0   A few days ago, DonaldTrump despicable spawn ...      8.72  0.273561
# 1   A group of over fifty former intelligence off...      9.16  0.381547
# 2   A new investigation has determined that Donal...      8.02  0.487670
# 3   A new video has emerged of the moments before...      7.23  0.490105
# 4   A ninety-six-year-old World War II veteran an...      8.21  0.426849
#
#       vs                                             tokens  \
# 0  0.696  [A, few, days, ago, DonaldTrump, despicable, s...
# 1  0.865  [A, group, of, over, fifty, former, intelligen...
# 2  0.855  [A, new, investigation, has, determined, that,...
# 3  0.770  [A, new, video, has, emerged, of, the, moments...
# 4  0.740  [A, ninety, six, year, old, World, War, II, ve...
#
#                                                lemma  avg_word_len  \
# 0  A few day ago DonaldTrump despicable spawn twe...      5.031359
# 1  A group of over fifty former intelligence offi...      5.323741
# 2  A new investigation ha determined that DonaldT...      4.937962
# 3  A new video ha emerged of the moment before an...      4.492105
# 4  A ninety six year old World War II veteran and...      4.645331
#
#    text_length
# 0          287
# 1          556
# 2          677
# 3          380
# 4          953

# %%
df.dropna(inplace = True)

# %%
cvec = CountVectorizer(stop_words='english', ngram_range=(1, 2), max_df = .8, min_df = 3)
X = cvec.fit_transform(df['lemma'])

X_full =  hstack((X,np.array(df['sub'])[:,None]))

X_full =  hstack((X,np.array(df['vs'])[:,None]))

X_full =  hstack((X,np.array(df['dc_score'])[:,None]))

X_full =  hstack((X,np.array(df['text_length'])[:,None]))

X_full =  hstack((X,np.array(df['avg_word_len'])[:,None]))

X_full.shape

y = df['label']

X_train, X_test, y_train, y_test = train_test_split(X_full, y,
                                                    random_state=42, stratify = y)

nb = MultinomialNB()

nb = MultinomialNB()
nb.fit(X_train, y_train)
print(nb.score(X_train, y_train))
print(nb.score(X_test, y_test))
# Out:
# 0.898042414355628
# 0.6650366748166259

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    random_state=42, stratify = y)

nb = MultinomialNB()

nb = MultinomialNB()
nb.fit(X_train, y_train)
print(nb.score(X_train, y_train))
print(nb.score(X_test, y_test))
# Out:
# 0.901305057096248
# 0.6699266503667481

# %%
rf = RandomForestClassifier()

pgrid_rf = {
    'n_estimators' : [5, 25, 50, 100],
    'max_depth' : [4, 5, 6, 8],
    'max_features' : [None, 8, 16]
    
}

# %%
X_train, X_test, y_train, y_test = train_test_split(X_full, y,
                                                    random_state=42, stratify = y)


gs_rf = GridSearchCV(rf, pgrid_rf, cv = 5, n_jobs = -1, verbose = 1)

gs_rf.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   17.1s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 240 out of 240 | elapsed:  1.9min finished
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=RandomForestClassifier(bootstrap=True, class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators='warn', n_jobs=None,
#                                               oob_score=False,
#                                               random_state=None, verbose=0,
#                                               warm_start=False),
#              iid='warn', n_jobs=-1,
#              param_grid={'max_depth': [4, 5, 6, 8],
#                          'max_features': [None, 8, 16],
#                          'n_estimators': [5, 25, 50, 100]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=1)

# %%
gs_rf.score(X_train, y_train)
# Out:
# 0.7251223491027733

# %%
gs_rf.score(X_test, y_test)
# Out:
# 0.706601466992665
